# %%
import pandas as pd

# %%
df = pd.read_csv("Registration Rates v Turnout Rates.csv")
newdf= df.rename(columns={"Registration Rate/County":"Registration_rate","zip code":"Zip_code","Turnout Rate": "Turnout_rate","latitude":"Latitude","longitude":"Longitude"})
newdf["Zip_code"].dtypes
# Out:
# dtype('int64')

# %%
df1 = pd.read_csv("Voting .csv")
newdf1 = df1.rename(columns={"zip code":"Zip_code","population":"Population","num registerd voters":"Num_registered_voters","num voted":"Num_voted","did not vote": "Did_not_vote","average house value":"Average_house_value","average income":"Average_income","latitude":"Latitude","longitude":"Longitude"})
#newdf1["Zip_code"].dtypes
newdf1
# Out:
#     Zip_code  Population  num registered voters Num_voted Did_not_vote  \
# 0    33626.0     33535.0                33382.0    14,115       19,267
# 1    33629.0     24930.0                34542.0    15,507       19,035
# 2    33634.0     22560.0                19609.0     7,468       12,141
# 3    33635.0     18517.0                18163.0     7,113       11,050
# 4    33637.0     18417.0                16651.0     6,352       10,299
# 5    33701.0     19376.0                25175.0    10,330       14,845
# 6    33801.0     32970.0                28474.0    10,579       17,895
# 7    33803.0     29675.0                31091.0    13,167       17,924
# 8    33805.0     27347.0                24203.0     9,086       15,117
# 9    33974.0     17770.0                11765.0     4,207        7,558
# 10   33976.0     17170.0                10347.0     3,577        6,770
# 11   33980.0     13407.0                13897.0     6,029        7,868
# ...

# %%
newdf2 = newdf1.apply (pd.to_numeric, errors='coerce')
newdf2
# Out:
#     Zip_code  Population  num registered voters  Num_voted  Did_not_vote  \
# 0    33626.0     33535.0                33382.0        NaN           NaN
# 1    33629.0     24930.0                34542.0        NaN           NaN
# 2    33634.0     22560.0                19609.0        NaN           NaN
# 3    33635.0     18517.0                18163.0        NaN           NaN
# 4    33637.0     18417.0                16651.0        NaN           NaN
# 5    33701.0     19376.0                25175.0        NaN           NaN
# 6    33801.0     32970.0                28474.0        NaN           NaN
# 7    33803.0     29675.0                31091.0        NaN           NaN
# 8    33805.0     27347.0                24203.0        NaN           NaN
# 9    33974.0     17770.0                11765.0        NaN           NaN
# 10   33976.0     17170.0                10347.0        NaN           NaN
# 11   33980.0     13407.0                13897.0        NaN           NaN
# ...
