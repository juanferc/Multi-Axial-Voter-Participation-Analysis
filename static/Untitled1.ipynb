# %%
import pandas as pd

# %%
df = pd.read_csv("Florida_data.csv")
df
# Out:
#      Zip_CoDE  less_than_grade_9_est  high_school_non_grad_est  \
# 0       33626                    165                       444
# 1       33629                    305                       166
# 2       33634                    838                      1250
# 3       33635                    330                       697
# 4       33637                    450                       539
# ..        ...                    ...                       ...
# 111     32904                    306                      1247
# 112     32905                    641                      1603
# 113     32907                    936                      1990
# 114     32908                    327                       365
# 115     32909                   1113                      1182
#
#      high_school_grad_est  some_college_no_degree_est  associates_degree_est  \
# 0                    2529                        3183                   1661
# 1                    2263                        2425                   1118
# 2                    4248                        2717                   1294
# 3                    3495                        2869                   1345
# 4                    2549                        2188                   1037
# ..                    ...                         ...                    ...
# 111                  6106                        4188                   2422
# 112                  5366                        3862                   2199
# 113                 10072                        7433                   3233
# 114                  2941                        1931                    805
# 115                  7462                        5247                   2333
#
#      bachelor_degree_est  grad_or_professional_degree_est registration_rate  \
# 0                   7030                             4525               65%
# 1                   6512                             5457               65%
# 2                   2988                             1290               65%
# 3                   2214                             1407               65%
# 4                   2216                             1071               65%
# ..                   ...                              ...               ...
# 111                 4125                             2497               NaN
# 112                 2102                              968               NaN
# 113                 4137                             1794               NaN
# 114                  910                              310               NaN
# 115                 2111                             1407               NaN
#
#     turnout_rate   latitude  longitude  population  num_registered_voters  \
# 0            42%  28.067196 -82.613677     33535.0                33382.0
# 1            69%  27.921808 -82.508953     24930.0                34542.0
# 2            38%  28.003866 -82.545317     22560.0                19609.0
# 3            39%  28.016174 -82.611958     18517.0                18163.0
# 4            38%  28.049979 -82.363446     18417.0                16651.0
# ..           ...        ...        ...         ...                    ...
# 111          NaN        NaN        NaN         NaN                    NaN
# 112          NaN        NaN        NaN         NaN                    NaN
# 113          NaN        NaN        NaN         NaN                    NaN
# 114          NaN        NaN        NaN         NaN                    NaN
# 115          NaN        NaN        NaN         NaN                    NaN
#
#     num_voted did_not_vote average_house_value average_income
# 0      14,115       19,267             347,700        106,560
# 1      15,507       19,035             492,300        115,180
# 2       7,468       12,141             162,400         58,013
# 3       7,113       11,050             164,700         60,267
# 4       6,352       10,299             146,000         52,635
# ..        ...          ...                 ...            ...
# 111       NaN          NaN                 NaN            NaN
# 112       NaN          NaN                 NaN            NaN
# 113       NaN          NaN                 NaN            NaN
# 114       NaN          NaN                 NaN            NaN
# 115       NaN          NaN                 NaN            NaN
#
# [116 rows x 18 columns]

# %%
df["Zip_CoDE"] = df["Zip_CoDE"].astype(str)

# %%
df.to_csv("FinalData.csv", index=False)
